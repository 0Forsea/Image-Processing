# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
from google.colab.patches import cv2_imshow

img = cv2.imread('/content/drive/MyDrive/ColabPhotos/road.png')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=300x223 at 0x7F87CEA1E340>

# %%
gray_image = cv2.imread('/content/drive/MyDrive/ColabPhotos/road.png',0)

cv2_imshow(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=300x223 at 0x7F87CE82DD00>

# %%
(thresh, blackAndWhiteImage) = cv2.threshold(gray_image, 20, 255, cv2.THRESH_BINARY)
print("20, 255")
cv2_imshow(blackAndWhiteImage)
(thresh, blackAndWhiteImage) = cv2.threshold(gray_image, 80, 255, cv2.THRESH_BINARY)
print("80, 255")
cv2_imshow(blackAndWhiteImage)
(thresh, blackAndWhiteImage) = cv2.threshold(gray_image, 160, 255, cv2.THRESH_BINARY)
print("160, 255")
cv2_imshow(blackAndWhiteImage)
(thresh, blackAndWhiteImage) = cv2.threshold(gray_image, 200, 255, cv2.THRESH_BINARY)
print("200, 255")
cv2_imshow(blackAndWhiteImage)
# Out:
# 20, 255
# <PIL.Image.Image image mode=L size=300x223 at 0x7F87CE9B8B50>
# 80, 255
# <PIL.Image.Image image mode=L size=300x223 at 0x7F87CE8EA160>
# 160, 255
# <PIL.Image.Image image mode=L size=300x223 at 0x7F87CE8FC4F0>
# 200, 255
# <PIL.Image.Image image mode=L size=300x223 at 0x7F87CE6DE880>

# %%
output2 = cv2.blur(gray_image, (10, 10))
print("Blur:")
cv2_imshow(output2)

output2 = cv2.GaussianBlur(gray_image, (9, 9), 5)
print("GaussianBlur :")
cv2_imshow(output2)
# Out:
# Blur:
# <PIL.Image.Image image mode=L size=300x223 at 0x7F87CE8EFF70>
# GaussianBlur:
# <PIL.Image.Image image mode=L size=300x223 at 0x7F87D12E6C10>

# %%
img = cv2.imread('/content/drive/MyDrive/ColabPhotos/road.png')
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
(thresh, output2) = cv2.threshold(gray_image, 200, 255, cv2.THRESH_BINARY)
output2 = cv2.Canny(output2, 180, 255)
cv2_imshow(output2)

lines = cv2.HoughLinesP(output2, 1, np.pi/180,30)
for line in lines:
    x1,y1,x2,y2 = line[0]
    cv2.line(img,(x1,y1),(x2,y2),(0,255,0),4)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=300x223 at 0x7F87CE6446D0>
# <PIL.Image.Image image mode=RGB size=300x223 at 0x7F87CE672DF0>
